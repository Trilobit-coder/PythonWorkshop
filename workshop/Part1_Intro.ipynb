# %% [markdown]
# <table align="center">
#   <!-- ASSTIA link -->
#   <td align="center">
#     <a target="_blank" href="https://github.com/SSTIA">
#       <img src="images/SSTIA_logo.jpg" style="padding-bottom:5px;" />
#       Visit SSTIA
#     </a>
#   </td>
#
#   <!-- Google Colab link -->
#   <td align="center">
#     <a target="_blank" href="https://colab.research.google.com/github/Trilobit-coder/PythonWorkshop/blob/main/workshop/Part1_Intro.ipynb">
#       <img src="https://i.ibb.co/2P3SLwK/colab.png" style="padding-bottom:5px;" />
#       Run in Google Colab
#     </a>
#   </td>
#
#   <!-- GitHub source link -->
#   <td align="center">
#     <a target="_blank" href="https://github.com/Trilobit-coder/PythonWorkshop/blob/main/workshop/Part1_Intro.ipynb">
#       <img src="https://i.ibb.co/xfJbPmL/github.png" height="70px" style="padding-bottom:5px;" />
#       View Source on GitHub
#     </a>
#   </td>
# </table>

# %% [markdown]
# ## 2026 SSTIA Python Workshop

# %% [markdown]
# ## Part 1 : Introduction to Python -- Basic Python Features

# %% [markdown]
# ### 1.0 Environment Testing

# %% [markdown]
# If you click the execute cell button below and print successfully, then it means your environment is correct

# %%
import random

print("Hello World")

# %% [markdown]
# Python is the most popular language in the world, which boasts a rich set of deleopment tools and frameworks and high readability coding style. If you are building a project where performance doesn't really counts, Python is probably one of the best choices! Also, it is the most widely used language in AI developing and deeping learning areas. So Python is something really worth learning. So... Let's go!

# %% [markdown]
# ### 1.1 Python -- a language with high readability

# %% [markdown]
# Let's first imagine we want to make a number bomb game, a simple game that user guess a number with hint larger or smaller until it's correct. So let's fisrt write a **pseudocode** to implement a number bomb with a random answer from 1 to 100 to show our algorithm.

# %% [markdown]
# ```py
# secret_number = randint(1,100)
#
# user_guess = input("Please enter a number: ")
#
# while user_guess != secret_number:
#     if secret_number > user_guess:
#         print("Incorrect. The answer is larger")
#     if secret_number < user_guess:
#         print("Incorrect. The answer is smaller")
#     # make a new guess
#     user_guess = input("Please enter a number: ")
#
# print("Correct")
# ```

# %% [markdown]
# And a Python implement looks like this

# %%
secret_number = random.randint(1,100)

user_guess = int(input("Please enter a number: "))

while user_guess != secret_number:
    if secret_number > user_guess:
        print("Incorrect. The answer is larger")
    if secret_number < user_guess:
        print("Incorrect. The answer is smaller")
    # make a new guess
    user_guess = int(input("Please enter a number: "))

print("Correct")

# %% [markdown]
# Pay attention to the difference here. What I do to change it from a pseudocode to a valid python code, is just add `random.` prefix to indicate is a function come from `random` library and a `int()` to change the input from string to int.
#
# This demonstrates the simplicity of the Python language.
